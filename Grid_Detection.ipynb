# %% [markdown]
# # Radial Distortions and Tangental Distortions

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread("flat_chess.jpeg")
flat_chess = cv2.cvtColor(flat_chess, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chess)
plt.show()

# %%
found, corners = cv2.findChessboardCorners(flat_chess, (7,7))

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 62.018356,  61.99925 ]],
#
#        [[124.51555 ,  61.984215]],
#
#        [[186.9067  ,  62.016953]],
#
#        [[249.491   ,  62.002438]],
#
#        [[311.97858 ,  62.018776]],
#
#        [[374.49557 ,  61.932137]],
#
#        [[436.99786 ,  62.007626]],
#
#        [[ 61.955963, 124.51004 ]],
#
#        [[124.51185 , 124.49449 ]],
#
#        [[186.98706 , 124.48213 ]],
#
#        [[249.4951  , 124.51174 ]],
#
#        [[311.9887  , 124.47124 ]],
#
#        [[374.49832 , 124.51052 ]],
#
#        [[436.96786 , 124.5022  ]],
#
#        [[ 62.056114, 187.05235 ]],
#
#        [[124.50466 , 186.9156  ]],
#
#        [[187.03223 , 186.9913  ]],
#
#        [[249.4984  , 187.00009 ]],
#
#        [[312.01248 , 187.00188 ]],
#
#        [[374.49832 , 186.923   ]],
#
#        [[436.90717 , 186.973   ]],
#
#        [[ 62.014923, 249.50945 ]],
#
#        [[124.50991 , 249.49477 ]],
#
#        [[187.00555 , 249.51402 ]],
#
#        [[249.49907 , 249.48499 ]],
#
# ...

# %%
cv2.drawChessboardCorners(flat_chess,(7,7), corners, found)
# Out:
# array([[[253, 247,   3],
#         [254, 250,   5],
#         [253, 252,   4],
#         ...,
#         [251,   3,   3],
#         [249,   4,   3],
#         [250,   5,   2]],
#
#        [[254, 250,   5],
#         [254, 253,   5],
#         [254, 254,   6],
#         ...,
#         [249,   1,   1],
#         [250,   2,   2],
#         [248,   3,   2]],
#
#        [[253, 252,   4],
#         [254, 254,   6],
#         [253, 255,   6],
#         ...,
#         [249,   1,   2],
#         [249,   1,   1],
#         [248,   3,   2]],
#
#        ...,
#
#        [[250,   2,   2],
#         [249,   1,   1],
#         [249,   1,   2],
#         ...,
#         [254, 255,   4],
#         [254, 253,   5],
#         [255, 251,   4]],
#
#        [[249,   4,   3],
#         [250,   2,   2],
#         [250,   2,   2],
#         ...,
#         [255, 255,   7],
#         [255, 254,   6],
#         [255, 251,   6]],
#
#        [[250,   5,   2],
#         [249,   4,   3],
#         [251,   3,   3],
# ...

# %%
plt.imshow(flat_chess)

# %%
dots = cv2.imread("dots2.png")
flat_chess = cv2.cvtColor(dots, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(dots)

# %%
found, corners = cv2.findCirclesGrid(dots, (4,4), cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 25.488232,  18.076107]],
#
#        [[146.51933 ,  18.251925]],
#
#        [[263.75797 ,  18.059017]],
#
#        [[382.84146 ,  18.084892]],
#
#        [[ 25.5     , 137.46176 ]],
#
#        [[144.5632  , 137.4368  ]],
#
#        [[263.7641  , 137.45598 ]],
#
#        [[382.78854 , 137.46785 ]],
#
#        [[ 25.459784, 256.8025  ]],
#
#        [[144.57405 , 256.7905  ]],
#
#        [[263.71997 , 256.82755 ]],
#
#        [[382.81497 , 256.81497 ]],
#
#        [[ 25.478556, 376.16022 ]],
#
#        [[144.59923 , 376.1654  ]],
#
#        [[263.74835 , 376.09888 ]],
#
#        [[382.82983 , 376.12634 ]]], dtype=float32)

# %%
cv2.drawChessboardCorners(dots,(4,4), corners, found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(dots)
