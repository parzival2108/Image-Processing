# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Contours are useful for shape analysis and objection detection and recognition. Contours are defined as curve joining all the continous points having same color or intensity.

# %%
img = cv2.imread("emos.jpeg",0)

# %%
plt.imshow(img, cmap = "gray")

# %%
img.shape
# Out:
# (363, 363)

# %%
plt.imshow(img, cmap = "gray")

# %%
_, c, h = cv2.findContours(img, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-4a0207b5d3dc> in <module>
# ----> 1 _, c, h = cv2.findContours(img, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
#
# ValueError: not enough values to unpack (expected 3, got 2)
