# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# chess = cv2.imread("flat_chess.jpeg")
# chess = cv2.cvtColor(chess, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Feature Matching
# - extracts defining key features from an input image using tools such as corner, ege and contour detection. Further it uses distance.

# %%
def display(img, cmap = "gray"):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap = "gray")

# %%
reeses = cv2.imread("reeses.png",0)

# %%
display(reeses)

# %%
cereals = cv2.imread("cereal-aisle.jpeg",0)

# %%
display(cereals)

# %% [markdown]
# # Brute Force Detection

# %%
orb = cv2.ORB_create()

# %%
kp1, des1 = orb.detectAndCompute(reeses,None)
kp2, des2 = orb.detectAndCompute(cereals,None)

# %%
bf = cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck = True)

# %%
matches = bf.match(des1,des2)

# %%
matches = sorted(matches, key = lambda x:x.distance)

# %%
matches
# Out:
# [<DMatch 0x7f9f5094b490>,
#  <DMatch 0x7f9f500756b0>,
#  <DMatch 0x7f9f502767d0>,
#  <DMatch 0x7f9f50276b90>,
#  <DMatch 0x7f9f503f4850>,
#  <DMatch 0x7f9f50075310>,
#  <DMatch 0x7f9f50276b10>,
#  <DMatch 0x7f9f503f4630>,
#  <DMatch 0x7f9f50075210>,
#  <DMatch 0x7f9f50276b50>,
#  <DMatch 0x7f9f503f46f0>,
#  <DMatch 0x7f9f503f4550>,
#  <DMatch 0x7f9f5094bcf0>,
#  <DMatch 0x7f9f502768f0>,
#  <DMatch 0x7f9f50276370>,
#  <DMatch 0x7f9f50075af0>,
#  <DMatch 0x7f9f5094bcd0>,
#  <DMatch 0x7f9f5094b0f0>,
#  <DMatch 0x7f9f502762d0>,
#  <DMatch 0x7f9f503f4c50>,
#  <DMatch 0x7f9f50075590>,
#  <DMatch 0x7f9f500752d0>,
#  <DMatch 0x7f9f5094b4f0>,
#  <DMatch 0x7f9f5094bd30>,
#  <DMatch 0x7f9f5094bed0>,
#  <DMatch 0x7f9f50276650>,
#  <DMatch 0x7f9f503f4970>,
#  <DMatch 0x7f9f503f4f70>,
#  <DMatch 0x7f9f5094be90>,
#  <DMatch 0x7f9f50276f30>,
#  <DMatch 0x7f9f503f4670>,
#  <DMatch 0x7f9f503f4fb0>,
#  <DMatch 0x7f9f500757d0>,
#  <DMatch 0x7f9f50075b10>,
#  <DMatch 0x7f9f5094ba10>,
# ...

# %%
single_match = matches[0]

# %%
single_match.distance
# Out:
# 32.0

# %%
len(matches)
# Out:
# 134

# %%
reeses_matches = cv2.drawMatches(reeses,kp1,cereals, kp2, matches[:25], None, flags = 2)

# %%
display(reeses_matches)
