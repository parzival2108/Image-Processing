# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
plt.figure(figsize=(10,10))
img1 = cv2.imread("hip.jpeg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
def load_img():
    
    img1 = cv2.imread("hip.jpeg").astype(np.float32)/255
    img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
    return img1

# %%
def display_img(img1):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    ax.imshow(img1)

# %%
i = load_img()
display_img(i)

# %%
plt.figure(figsize=(10,10))
img2 = cv2.imread("smile.jpeg")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
plt.figure(figsize=(10,10))
img3= cv2.imread("showingbutt.jpeg")
img3 = cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
hist_values_1= cv2.calcHist([img1],channels = [0], mask = None, histSize = [256], ranges = [0,256])

# %%
his_values.shape
# Out:
# (256, 1)

# %%
plt.plot(his_values)

# %%
hist_values_2= cv2.calcHist([img2],channels = [0], mask = None, histSize = [256], ranges = [0,256])

# %%
plt.plot(hist_values)

# %%
hist_values_3= cv2.calcHist([img3],channels = [0], mask = None, histSize = [256], ranges = [0,256])

# %%
plt.figure(figsize=(12,12))
plt.plot(hist_values_1)
plt.plot(hist_values_2)
plt.plot(hist_values_3)
plt.xlim([0,50])
plt.ylim([0,500000])
# Out:
# (0.0, 500000.0)
